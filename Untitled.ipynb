# %%
# %matplotlib inline

import random

import numpy as np

from skcriteria import Data

# %%
mtx = np.random.rand(48, 15)
criteria = np.asarray([random.choice((1, -1)) for e in range(15)])
weights = np.random.randint(1, 100, 15)
data = Data(mtx, criteria, weights)
data
# Out:
#  ALT./CRIT.    C0 (max) W.92    C1 (min) W.83    C2 (min) W.6    C3 (min) W.86    C4 (min) W.81    C5 (min) W.81    C6 (min) W.39    C7 (max) W.19    C8 (max) W.63    C9 (max) W.44    C10 (min) W.10    C11 (max) W.99    C12 (max) W.59    C13 (min) W.48    C14 (max) W.18
# ------------  ---------------  ---------------  --------------  ---------------  ---------------  ---------------  ---------------  ---------------  ---------------  ---------------  ----------------  ----------------  ----------------  ----------------  ----------------
#      A0          0.399992         0.968418         0.367941        0.0497298        0.0880277        0.885716         0.0463679        0.958625         0.0193953        0.0996323         0.809219          0.847927          0.131362          0.664308          0.233719
# ...

# %%
from skcriteria.plot import radar
reload(radar)
data.plot.radar(cmap="inferno", wnorm="sum", title="foo")
