# %% [markdown]
# # Data Manipulation tutorial

# %%
# %matplotlib inline

from skcriteria import Data, MIN, MAX, datasets
from skcriteria.madm import closeness

# %%
data = datasets.load_camera()
data
# Out:
#             ALT./CRIT.               Release date (max)    Max resolution (max)    Low resolution (max)    Effective pixels (max)    Zoom wide (W) (max)    Zoom tele (T) (max)    Normal focus range (max)    Macro focus range (max)    Storage included (max)    Weight (inc. batteries) (min)    Dimensions (min)    Price (min)
# ----------------------------------  --------------------  ----------------------  ----------------------  ------------------------  ---------------------  ---------------------  --------------------------  -------------------------  ------------------------  -------------------------------  ------------------  -------------
#          Agfa ePhoto 1280                   1997                   1024                    640                       0                       38                     114                       70                         40                         4                            420                        95               179
# ...

# %%
data.plot.b()
# Out:
# /home/juan/proyectos/scikit-criteria/local/lib/python2.7/site-packages/numpy/linalg/linalg.py:1804: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/juan/proyectos/scikit-criteria/local/lib/python2.7/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
